# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %%
# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
# Create the CNN model
cnn_model = models.Sequential()
cnn_model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
cnn_model.add(layers.MaxPooling2D((2, 2)))
cnn_model.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn_model.add(layers.MaxPooling2D((2, 2)))
cnn_model.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn_model.add(layers.Flatten())
cnn_model.add(layers.Dense(64, activation='relu'))
cnn_model.add(layers.Dense(10, activation='softmax'))

# %%
# Compile the CNN model
cnn_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
# Train the CNN model
cnn_history = cnn_model.fit(train_images, train_labels, epochs=10, batch_size=64,
                            validation_data=(test_images, test_labels))

# Evaluate the CNN model
test_loss, test_acc = cnn_model.evaluate(test_images, test_labels)
print(f'CNN Test Accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 10s 6ms/step - loss: 1.5663 - accuracy: 0.4277 - val_loss: 1.2880 - val_accuracy: 0.5407
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 1.1864 - accuracy: 0.5794 - val_loss: 1.1040 - val_accuracy: 0.6128
# Epoch 3/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.0416 - accuracy: 0.6348 - val_loss: 1.0185 - val_accuracy: 0.6430
# Epoch 4/10
# 782/782 [==============================] - 4s 6ms/step - loss: 0.9372 - accuracy: 0.6701 - val_loss: 0.9442 - val_accuracy: 0.6742
# Epoch 5/10
# 782/782 [==============================] - 4s 6ms/step - loss: 0.8657 - accuracy: 0.6981 - val_loss: 0.9049 - val_accuracy: 0.6915
# Epoch 6/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.8070 - accuracy: 0.7176 - val_loss: 0.8952 - val_accuracy: 0.6964
# Epoch 7/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.7633 - accuracy: 0.7331 - val_loss: 0.8526 - val_accuracy: 0.7067
# Epoch 8/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.7180 - accuracy: 0.7490 - val_loss: 0.8670 - val_accuracy: 0.7045
# Epoch 9/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6850 - accuracy: 0.7612 - val_loss: 0.9054 - val_accuracy: 0.6929
# Epoch 10/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6472 - accuracy: 0.7741 - val_loss: 0.8721 - val_accuracy: 0.7107
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8721 - accuracy: 0.7107
# CNN Test Accuracy: 0.7106999754905701

# %%
# Import necessary libraries for RNN
from tensorflow.keras.layers import LSTM, Embedding, Dense

# Load and preprocess the CIFAR-10 dataset (flatten the images for RNN)
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images = train_images.reshape((50000, 32 * 32 * 3))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 32 * 32 * 3))
test_images = test_images.astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Create the RNN model
rnn_model = models.Sequential()
rnn_model.add(Embedding(input_dim=32 * 32 * 3, output_dim=128))
rnn_model.add(LSTM(64))
rnn_model.add(Dense(10, activation='softmax'))

# %%
# Compile the RNN model
rnn_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
# Train the RNN model
rnn_history = rnn_model.fit(train_images, train_labels, epochs=10, batch_size=64,
                            validation_data=(test_images, test_labels))

# Evaluate the RNN model
test_loss, test_acc = rnn_model.evaluate(test_images, test_labels)
print(f'RNN Test Accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 85s 105ms/step - loss: 2.3000 - accuracy: 0.1024 - val_loss: 2.2984 - val_accuracy: 0.1043
# Epoch 2/10
# 782/782 [==============================] - 82s 104ms/step - loss: 2.2986 - accuracy: 0.1036 - val_loss: 2.2976 - val_accuracy: 0.1043
# Epoch 3/10
# 782/782 [==============================] - 82s 105ms/step - loss: 2.2983 - accuracy: 0.1023 - val_loss: 2.2972 - val_accuracy: 0.1062
# Epoch 4/10
# 782/782 [==============================] - 82s 105ms/step - loss: 2.2939 - accuracy: 0.1075 - val_loss: 2.2629 - val_accuracy: 0.1344
# Epoch 5/10
# 782/782 [==============================] - 76s 98ms/step - loss: 2.2718 - accuracy: 0.1305 - val_loss: 2.2675 - val_accuracy: 0.1334
# Epoch 6/10
# 782/782 [==============================] - 76s 98ms/step - loss: 2.2952 - accuracy: 0.1070 - val_loss: 2.2718 - val_accuracy: 0.1349
# Epoch 7/10
# 782/782 [==============================] - 83s 107ms/step - loss: 2.2672 - accuracy: 0.1352 - val_loss: 2.2642 - val_accuracy: 0.1403
# Epoch 8/10
# 782/782 [==============================] - 77s 98ms/step - loss: 2.2649 - accuracy: 0.1382 - val_loss: 2.2628 - val_accuracy: 0.1390
# Epoch 9/10
# 782/782 [==============================] - 77s 98ms/step - loss: 2.2651 - accuracy: 0.1391 - val_loss: 2.2608 - val_accuracy: 0.1436
# Epoch 10/10
# 782/782 [==============================] - 77s 99ms/step - loss: 2.2684 - accuracy: 0.1373 - val_loss: 2.2606 - val_accuracy: 0.1417
# 313/313 [==============================] - 12s 38ms/step - loss: 2.2606 - accuracy: 0.1417
# RNN Test Accuracy: 0.14169999957084656
